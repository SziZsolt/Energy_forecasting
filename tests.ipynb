# %%
# !pip install pytest
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytest]2m2/3 [pytest]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from My_Tests import *

# %%
test_positional_encoding_shape()
test_positional_encoding_variation()
test_multihead_attention_output_shape()
test_multihead_attention_masked()
test_cross_attention_output_shape()
test_feedforward_output_shape()
test_feedforward_residual_connection()
test_encoder_forward_pass()
test_decoder_forward_pass()
test_full_transformer_model_forward()
test_transformer_gradients()
test_no_nan_outputs()
